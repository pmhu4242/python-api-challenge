# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint 

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 590

# %%
# Base url for api
url = "http://api.openweathermap.org/data/2.5/weather?"

# Create lists to store response data
weather_data = []
temp = []
humidity = []
cloud = []
wind = []
country = []
date = []
city_name = []

# Output record Counter and Total count
record= 1
total_record = len(cities)

# Units to convert Kelvin to Farenheight 
units = 'imperial'

# Print Intial Data Log Statement
print(f"Beginning Data Retrieval")
print(f"-------------------------------")

# Create a loop to go through all the cities & perform the requests for data on each entry
for city in cities:

    query_url = f"{url}appid={weather_api_key}&units={units}&q="

    response = requests.get(query_url + city).json()
#     print(response)
    try:
        city_name.append(response['name'])
        temp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        cloud.append(response['clouds']['all'])
        wind.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        
        print(f"Processing Record {record} of {total_record}  | {city}" )
        
#       Add to increase record count by one for each city 
        record += 1
    except:
         print("City not found. Skipping...") 
        
# Print Ending Data Log Statement 
print(f"-------------------------------")
print(f"Data Retrieval Complete")
print(f"-------------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 of 590  | turochak
# Processing Record 2 of 590  | bluff
# Processing Record 3 of 590  | verkhoyansk
# Processing Record 4 of 590  | hithadhoo
# Processing Record 5 of 590  | kapaa
# City not found. Skipping...
# Processing Record 6 of 590  | hermanus
# City not found. Skipping...
# Processing Record 7 of 590  | lebu
# City not found. Skipping...
# Processing Record 8 of 590  | lagoa
# Processing Record 9 of 590  | heihe
# Processing Record 10 of 590  | galveston
# Processing Record 11 of 590  | mehamn
# Processing Record 12 of 590  | faanui
# Processing Record 13 of 590  | klaksvik
# Processing Record 14 of 590  | vostok
# Processing Record 15 of 590  | busselton
# Processing Record 16 of 590  | ponta do sol
# Processing Record 17 of 590  | camocim
# Processing Record 18 of 590  | atuona
# City not found. Skipping...
# Processing Record 19 of 590  | tasiilaq
# Processing Record 20 of 590  | sao filipe
# Processing Record 21 of 590  | tuktoyaktuk
# City not found. Skipping...
# Processing Record 22 of 590  | peniche
# Processing Record 23 of 590  | la ronge
# Processing Record 24 of 590  | provideniya
# Processing Record 25 of 590  | nelson bay
# Processing Record 26 of 590  | albany
# Processing Record 27 of 590  | vaitape
# Processing Record 28 of 590  | zhongshu
# Processing Record 29 of 590  | te anau
# Processing Record 30 of 590  | arraial do cabo
# Processing Record 31 of 590  | college
# Processing Record 32 of 590  | promyshlennyy
# Processing Record 33 of 590  | port elizabeth
# Processing Record 34 of 590  | touros
# Processing Record 35 of 590  | puerto ayora
# Processing Record 36 of 590  | touba
# Processing Record 37 of 590  | thompson
# Processing Record 38 of 590  | kruisfontein
# Processing Record 39 of 590  | cape town
# Processing Record 40 of 590  | hobart
# Processing Record 41 of 590  | shimoda
# Processing Record 42 of 590  | keti bandar
# Processing Record 43 of 590  | isangel
# Processing Record 44 of 590  | shelburne
# Processing Record 45 of 590  | katobu
# Processing Record 46 of 590  | rikitea
# Processing Record 47 of 590  | tiksi
# Processing Record 48 of 590  | mount gambier
# Processing Record 49 of 590  | pisco
# City not found. Skipping...
# Processing Record 50 of 590  | punta arenas
# Processing Record 51 of 590  | chokurdakh
# Processing Record 52 of 590  | patnos
# Processing Record 53 of 590  | butaritari
# Processing Record 54 of 590  | valle de allende
# Processing Record 55 of 590  | waingapu
# Processing Record 56 of 590  | cheremkhovo
# City not found. Skipping...
# City not found. Skipping...
# Processing Record
# Processing Record 380 of 590  | palu
# Processing Record 381 of 590  | gravdal
# Processing Record 382 of 590  | kabare
# Processing Record 383 of 590  | kashima
# City not found. Skipping...
# Processing Record 384 of 590  | gangarampur
# Processing Record 385 of 590  | ketchikan
# Processing Record 386 of 590  | mingaora
# Processing Record 387 of 590  | gimli
# Processing Record 388 of 590  | weligama
# Processing Record 389 of 590  | bahawalpur
# Processing Record 390 of 590  | karratha
# Processing Record 391 of 590  | carutapera
# Processing Record 392 of 590  | katy
# Processing Record 393 of 590  | hue
# Processing Record 394 of 590  | vestmannaeyjar
# Processing Record 395 of 590  | talnakh
# Processing Record 396 of 590  | lavumisa
# Processing Record 397 of 590  | setermoen
# Processing Record 398 of 590  | guerrero negro
# Processing Record 399 of 590  | balabac
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 400 of 590  | wysokie mazowieckie
# City not found. Skipping...
# Processing Record 401 of 590  | krasnoselkup
# Processing Record 402 of 590  | santa isabel
# Processing Record 403 of 590  | daru
# Processing Record 404 of 590  | sao joao da barra
# Processing Record 405 of 590  | ellisras
# Processing Record 406 of 590  | methoni
# Processing Record 407 of 590  | andenes
# Processing Record 408 of 590  | hovd
# Processing Record 409 of 590  | caravelas
# Processing Record 410 of 590  | lodja
# City not found. Skipping...
# Processing Record 411 of 590  | moerai
# Processing Record 412 of 590  | newtownards
# Processing Record 413 of 590  | manaure
# Processing Record 414 of 590  | paamiut
# Processing Record 415 of 590  | westfield
# Processing Record 416 of 590  | katiola
# Processing Record 417 of 590  | gebze
# Processing Record 418 of 590  | louisville
# Processing Record 419 of 590  | santiago del estero
# Processing Record 420 of 590  | sambava
# City not found. Skipping...
# Processing Record 421 of 590  | launceston
# Processing Record 422 of 590  | arroyo
# Processing Record 423 of 590  | pangnirtung
# Processing Record 424 of 590  | ojinaga
# Processing Record 425 of 590  | chumikan
# Processing Record 426 of 590  | bikaner
# Processing Record 427 of 590  | fortuna
# Processing Record 428 of 590  | okhotsk
# City not found. Skipping...
# Processing Record 429 of 590  | channel-port aux basques
# Processing Record 430 of 590  | rawson
# Processing Record 431 of 590  | melfort
# Processing Record 432 of 590  | ponnani
# Processing Record 433 of 590  | turukhansk
# Processing Record 434 of 590  | vyartsilya
# Processing Record 435 of 590  | orlik
# Processing Record 436 of 590  | mantua
# Processing Record 437 of 590  | bengkulu
# Processing Record 438 of 590  | abalak
# Processing Record 439 of 590  | ohara
# Processing Record 440 of 590  | bojnurd
# Processing Record 441 of 590  | marystown
# Processing Record 442 of 590  | aban
# Processing Record 443 of 590  | chandler
# Processing Record 444 of 590  | nacala
# Processing Record 445 of 590  | atikokan
# Processing Record 446 of 590  | petropavlovsk-kamchatskiy
# Processing Record 447 of 590  | high level
# Processing Record 448 of 590  | scranton
# Processing Record 449 of 590  | hof
# Processing Record 450 of 590  | necochea
# Processing Record 451 of 590  | iwanai
# Processing Record 452 of 590  | aljezur
# Processing Record 453 of 590  | gazli
# Processing Record 454 of 590  | havre-saint-pierre
# Processing Record 455 of 590  | villa union
# Processing Record 456 of 590  | port-gentil
# Processing Record 457 of 590  | oistins
# Processing Record 458 of 590  | micheweni
# Processing Record 459 of 590  | ebolowa
# Processing Record 460 of 590  | alugan
# Processing Record 461 of 590  | gien
# Processing Record 462 of 590  | saint-pierre
# City not found. Skipping...
# Processing Record 463 of 590  | aripuana
# Processing Record 464 of 590  | yurimaguas
# Processing Record 465 of 590  | namibe
# Processing Record 466 of 590  | nadym
# Processing Record 467 of 590  | batagay-alyta
# Processing Record 468 of 590  | pacasmayo
# Processing Record 469 of 590  | krasnyy chikoy
# Processing Record 470 of 590  | ben tre
# Processing Record 471 of 590  | tartagal
# Processing Record 472 of 590  | kavaratti
# Processing Record 473 of 590  | princeton
# Processing Record 474 of 590  | walvis bay
# City not found. Skipping...
# Processing Record 475 of 590  | aksarka
# Processing Record 476 of 590  | baruun-urt
# Processing Record 477 of 590  | mandalgovi
# Processing Record 478 of 590  | bajil
# Processing Record 479 of 590  | baiyin
# Processing Record 480 of 590  | bilma
# Processing Record 481 of 590  | shu
# Processing Record 482 of 590  | tromso
# City not found. Skipping...
# Processing Record 483 of 590  | ukhta
# Processing Record 484 of 590  | mitsamiouli
# Processing Record 485 of 590  | watertown
# Processing Record 486 of 590  | sistranda
# Processing Record 487 of 590  | novaya ladoga
# Processing Record 488 of 590  | hegra
# Processing Record 489 of 590  | zhuhai
# Processing Record 490 of 590  | tual
# Processing Record 491 of 590  | gualeguaychu
# Processing Record 492 of 590  | boulder city
# Processing Record 493 of 590  | opuwo
# Processing Record 494 of 590  | mae sai
# Processing Record 495 of 590  | haimen
# Processing Record 496 of 590  | moron
# Processing Record 497 of 590  | dzhebariki-khaya
# Processing Record 498 of 590  | brae
# Processing Record 499 of 590  | zastron
# Processing Record 500 of 590  | palmer
# Processing Record 501 of 590  | hay river
# Processing Record 502 of 590  | anadyr
# Processing Record 503 of 590  | bubaque
# Processing Record 504 of 590  | suhbaatar
# Processing Record 505 of 590  | westport
# Processing Record 506 of 590  | toowoomba
# City not found. Skipping...
# Processing Record 507 of 590  | altagracia de orituco
# City not found. Skipping...
# Processing Record 508 of 590  | kholtoson
# Processing Record 509 of 590  | ola
# Processing Record 510 of 590  | bandarbeyla
# Processing Record 511 of 590  | sorata
# Processing Record 512 of 590  | meulaboh
# Processing Record 513 of 590  | quetta
# Processing Record 514 of 590  | birjand
# Processing Record 515 of 590  | conde
# Processing Record 516 of 590  | la sarre
# Processing Record 517 of 590  | gbarnga
# Processing Record 518 of 590  | krasnyy kut
# Processing Record 519 of 590  | yele
# Processing Record 520 of 590  | sechelt
# Processing Record 521 of 590  | bonthe
# Processing Record 522 of 590  | bacolod
# Processing Record 523 of 590  | nunspeet
# Processing Record 524 of 590  | la canada flintridge
# Processing Record 525 of 590  | dandeli
# Processing Record 526 of 590  | zhaotong
# City not found. Skipping...
# Processing Record 527 of 590  | betsiamites
# Processing Record 528 of 590  | cochabamba
# Processing Record 529 of 590  | fare
# Processing Record 530 of 590  | fort nelson
# Processing Record 531 of 590  | agadir
# Processing Record 532 of 590  | honiara
# -------------------------------
# Data Retrieval Complete
# -------------------------------

# %%
# Create a DataFrame containing 'City ', 'Country', 'Latitude', 'Longitude',  'Temperature', 'Humidity', 'Cloudiness', 'Wind Speed', 'Date'
weather_data = pd.DataFrame(( city_name, country, lats, lngs, temp, humidity, cloud, wind, date), 
                            index=('City ', 'Country', 'Latitude', 'Longitude',  'Temperature', 'Humidity', 'Cloudiness', 'Wind Speed', 'Date'), dtype='int64').T
# Display DataFrame 
weather_data.dtypes
# Out:
# City           object
# Country        object
# Latitude       object
# Longitude      object
# Temperature    object
# Humidity       object
# Cloudiness     object
# Wind Speed     object
# Date           object
# dtype: object

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-df5718747411> in <module>
# ----> 1 pd.to_numeric('Latitude', 'Longitude',  'Temperature', 'Humidity', 'Cloudiness', 'Wind Speed')
#
# TypeError: to_numeric() takes from 1 to 3 positional arguments but 6 were given

# %%
# Drop any rows containing missing values
weather_clean = weather_data.dropna(how='any')
weather_clean
# Out:
#            City  Country Latitude Longitude Temperature Humidity Cloudiness  \
# 0       Turochak      RU  51.5417   87.3225       38.39       80        100
# 1          Bluff      NZ -61.8749   160.528       46.99       94        100
# 2    Verkhoyansk      RU  68.5551   133.793      -17.68       86        100
# 3      Hithadhoo      MV -1.26899   64.7137       84.25       69          0
# 4          Kapaa      US  30.0949  -160.927        75.2       94         75
# ..           ...     ...      ...       ...         ...      ...        ...
# 527   Cochabamba      BO -82.9244   168.907        55.4       54         20
# 528         Fare      PF -85.1173  -148.987       79.83       81         26
# 529  Fort Nelson      CA  24.0581   53.9624        12.2       92         90
# 530   Santa Cruz      MA  28.8506   14.7518        64.4       63          0
# 531      Honiara      SB -70.1311  -58.2468        84.2       83         90
#
#     Wind Speed        Date
# 0         5.03  1604563707
# 1            7  1604563155
# 2         1.36  1604563708
# 3         5.39  1604563162
# 4         4.09  1604563708
# ..         ...         ...
# 527       0.72  1604563751
# 528      12.84  1604563806
# 529       3.36  1604563806
# 530      11.41  1604563806
# 531        4.7  1604563807
#
# [532 rows x 9 columns]

# %%
# Find any cities with humidty of greater than 100, if none skip this step
weather_cities = weather_clean.loc[(weather_clean['Humidity'] >100)]
# Out:
# City           object
# Country        object
# Latitude       object
# Longitude      object
# Temperature    object
# Humidity       object
# Cloudiness     object
# Wind Speed     object
# Date           object
# dtype: object

# %%
# Create individual scatter plots for temperature, humidty, cloudiness, and wind speed against latitude data

# Create scatter plot of temp vs latitude
plt.scatter(weather_clean['Latitude'], weather_clean['Temperature'], marker='o')

plt.title('Temperature (F) vs Latitude (11/05/2020)')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.grid(True)
plt.savefig("lat_vs_temp.png")
plt.show()

# The scatter plot below is displaying all the individual cities from the data table, use column names to populate the data for each axis, added labels and title
# The results don't seem to highlight any sort of correlation without further analysis of the data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-fa65f202ab67> in <module>
#      11 plt.show()
#      12
# ---> 13 The
#
# NameError: name 'The' is not defined

# %%
# Create scatter plot of humidity vs latitude

plt.scatter(weather_clean['Latitude'], weather_clean['Humidity'], marker='o')

plt.title('Temperature (F) vs Humidity (%) (11/05/2020)')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid(True)
plt.savefig("lat_vs_humidity.png")
plt.show()

# The scatter plot below is displaying all the individual cities from the data table, use column names to populate the data for each axis, added labels and title
# The results don't seem to highlight any sort of correlation without further analysis of the data

# %%
# Create scatter plot of cloudiness vs latitude

plt.scatter(weather_clean['Latitude'], weather_clean['Cloudiness'], marker='o')

plt.title('Cloudiness (%) vs Latitude (11/05/2020)')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid(True)
plt.savefig('lat_vs_cloudiness.png')
plt.show()

# The scatter plot below is displaying all the individual cities from the data table, use column names to populate the data for each axis, added labels and title
# The results don't seem to highlight any sort of correlation without further analysis of the data

# %%
# Create scatter plot of wind speed vs latitude

plt.scatter(weather_clean['Latitude'], weather_clean['Wind Speed'], marker='o')

plt.title('Wind Speed (mph) vs Latitude (11/05/2020)')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.grid(True)
plt.savefig('lat_vs_wind.png')
plt.show()

# The scatter plot below is displaying all the individual cities from the data table, use column names to populate the data for each axis, added labels and title
# The results don't seem to highlight any sort of correlation without further analysis of the data, there are possibly some outliers in this data which might skew the results

# %%
# Run a linear regression for each of the above conditions
# Create Data Tables for northern and southern hemispheres 
northern_hemi = weather_clean.loc[(weather_clean['Latitude'] >=0)]
northern_hemi.dtypes
# Out:
# City           object
# Country        object
# Latitude       object
# Longitude      object
# Temperature    object
# Humidity       object
# Cloudiness     object
# Wind Speed     object
# Date           object
# dtype: object

# %%
southern_hemi = weather_clean.loc[(weather_clean['Latitude'] <0)]
southern_hemi
# Out:
#                  City  Country Latitude Longitude Temperature Humidity  \
# 1                Bluff      NZ -61.8749   160.528       46.99       94
# 3            Hithadhoo      MV -1.26899   64.7137       84.25       69
# 6                 Lebu      CL -66.7742   2.24691       47.17       86
# 8                Heihe      CN -30.5526  -91.4646        30.2       46
# 14           Busselton      AU -11.1613  -152.772          81       22
# ..                 ...     ...      ...       ...         ...      ...
# 521       Bacolod City      PH -31.1887  -12.5721       78.71       85
# 522  Gemeente Nunspeet      NL -70.7704   51.2444          39       88
# 527         Cochabamba      BO -82.9244   168.907        55.4       54
# 528               Fare      PF -85.1173  -148.987       79.83       81
# 531            Honiara      SB -70.1311  -58.2468        84.2       83
#
#     Cloudiness Wind Speed        Date
# 1          100          7  1604563155
# 3            0       5.39  1604563162
# 6            0        7.4  1604563173
# 8           20       8.95  1604563709
# 14          44       7.94  1604563710
# ..         ...        ...         ...
# 521        100       2.86  1604563805
# 522          0       4.99  1604563805
# 527         20       0.72  1604563751
# 528         26      12.84  1604563806
# 531         90        4.7  1604563807
#
# [253 rows x 9 columns]

# %%
x_values = northern_hemi['Latitude']
y_values = northern_hemi['Temperature']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept
print(regress_values)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-f3582ff63736> in <module>
#       2 y_values = northern_hemi['Temperature']
#       3
# ----> 4 (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
#       5
#       6 # Get regression values
#
# ~\anaconda3\envs\PythonData\lib\site-packages\scipy\stats\_stats_mstats_common.py in linregress(x, y)
#     114
#     115     # average sum of squares:
# --> 116     ssxm, ssxym, ssyxm, ssym = np.cov(x, y, bias=1).flat
#     117     r_num = ssxym
#     118     r_den = np.sqrt(ssxm * ssym)
#
# <__array_function__ internals> in cov(*args, **kwargs)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\numpy\lib\function_base.py in cov(m, y, rowvar, bias, ddof, fweights, aweights)
#    2429             w *= aweights
#    2430
# -> 2431     avg, w_sum = average(X, axis=1, weights=w, returned=True)
#    2432     w_sum = w_sum[0]
#    2433
#
# <__array_function__ internals> in average(*args, **kwargs)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\numpy\lib\function_base.py in average(a, axis, weights, returned)
#     423
#     424     if returned:
# --> 425         if scl.shape != avg.shape:
#     426             scl = np.broadcast_to(scl, avg.shape).copy()
#     427         return avg, scl
#
# AttributeError: 'float' object has no attribute 'shape'
