# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import scipy.stats as st
from pprint import pprint 

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 628

# %%
# Base url for api
url = "http://api.openweathermap.org/data/2.5/weather?"

# Create lists to store response data
weather_data = []
temp = []
humidity = []
cloud = []
wind = []
country = []
date = []
city_name = []

# Output record Counter and Total count
record= 1
total_record = len(cities)

# Units to convert Kelvin to Farenheight 
units = 'imperial'

# Print Intial Data Log Statement
print(f"Beginning Data Retrieval")
print(f"-------------------------------")

# Create a loop to go through all the cities & perform the requests for data on each entry
for city in cities:

    query_url = f"{url}appid={weather_api_key}&units={units}&q="

    response = requests.get(query_url + city).json()
#     print(response)
    try:
        city_name.append(response['name'])
        temp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        cloud.append(response['clouds']['all'])
        wind.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        
        print(f"Processing Record {record} of {total_record}  | {city}" )
        
#       Add to increase record count by one for each city 
        record += 1
    except:
         print("City not found. Skipping...") 
        
# Print Ending Data Log Statement 
print(f"-------------------------------")
print(f"Data Retrieval Complete")
print(f"-------------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------------
# City not found. Skipping...
# Processing Record 1 of 628  | busselton
# Processing Record 2 of 628  | atuona
# Processing Record 3 of 628  | comodoro rivadavia
# Processing Record 4 of 628  | forbes
# Processing Record 5 of 628  | krasnoselkup
# City not found. Skipping...
# Processing Record 6 of 628  | soto la marina
# Processing Record 7 of 628  | longyearbyen
# Processing Record 8 of 628  | tomakivka
# Processing Record 9 of 628  | katsuura
# Processing Record 10 of 628  | black river
# Processing Record 11 of 628  | hit
# Processing Record 12 of 628  | badou
# Processing Record 13 of 628  | puerto escondido
# Processing Record 14 of 628  | yamada
# Processing Record 15 of 628  | ushuaia
# Processing Record 16 of 628  | te anau
# Processing Record 17 of 628  | new norfolk
# Processing Record 18 of 628  | saskylakh
# Processing Record 19 of 628  | karasuk
# Processing Record 20 of 628  | coihaique
# Processing Record 21 of 628  | faanui
# Processing Record 22 of 628  | tezu
# Processing Record 23 of 628  | ponta delgada
# Processing Record 24 of 628  | butaritari
# Processing Record 25 of 628  | richmond
# City not found. Skipping...
# Processing Record 26 of 628  | puerto ayora
# Processing Record 27 of 628  | margate
# Processing Record 28 of 628  | santiago
# Processing Record 29 of 628  | yellowknife
# Processing Record 30 of 628  | saint-philippe
# Processing Record 31 of 628  | norman wells
# Processing Record 32 of 628  | zakamensk
# Processing Record 33 of 628  | tabou
# Processing Record 34 of 628  | husavik
# Processing Record 35 of 628  | vaini
# Processing Record 36 of 628  | waycross
# Processing Record 37 of 628  | lashio
# Processing Record 38 of 628  | asyut
# Processing Record 39 of 628  | tuktoyaktuk
# Processing Record 40 of 628  | turan
# Processing Record 41 of 628  | juliaca
# Processing Record 42 of 628  | awjilah
# Processing Record 43 of 628  | boende
# Processing Record 44 of 628  | cartagena
# City not found. Skipping...
# Processing Record 45 of 628  | bluff
# City not found. Skipping...
# Processing Record 46 of 628  | cam ranh
# Processing Record 47 of 628  | murray bridge
# Processing Record 48 of 628  | kodiak
# Processing Record 49 of 628  | ahuimanu
# Processing Record 50 of 628  | matara
# City not found. Skipping...
# Processing Record 51 of 628  | east london
# Processing Record 52 of 628  | rikitea
# Processing Record 53 of 628  | namibe
# City not found. Skipping...
# Processing Record 54 of 628  | rangoon
# Processing Record 55 of 628  | la ronge
# Processing Record 56 of 628  | georgetown
# City not found. Skipping...
# Processing Record 57 of 628  | ilulissat
# Processing Record 58 of 628  | kimamba
# Processing Record 59 of 628  | hobart
# Processing Record 60 of 628  | castro
# Processing Record 61 of 628  | cayenne
# Processing Record 62 of 628  | abha
# Processing Record 63 of 628  | jamestown
# City not found. Skipping...
# Processing Record 64 of 628  | sagarejo
# Processing Record 65 of 628  | punta arenas
# Processing Record 66 of 628  | chuy
# Processing Record 67 of 628  | tura
# Processing Record 68 of 628  | saint-joseph
# Processing Record 69 of 628  | tambura
# Processing Record 70 of 628  | camrose
# Processing Record 71 of 628  | arraial do cabo
# Processing Record 72 of 628  | lompoc
# Processing Record 73 of 628  | hermanus
# City not found. Skipping...
# Processing Record 74 of 628  | shakawe
# Processing Record 75 of 628  | zhangye
# Processing Record 76 of 628  | qaanaaq
# Processing Record 77 of 628  | hilo
# Processing Record 78 of 628  | airai
# Processing Record 79 of 628  | vaitape
# Processing Record 80 of 628  | xai-xai
# Processing Record 81 of 628  | mahebourg
# Processing Record 82 of 628  | tamandare
# Processing Record 83 of 628  | san quintin
# Processing Record 84 of 628  | mwene-ditu
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 85 of 628  | bengkulu
# Processing Record 86 of 628  | tucurui
# Processing Record 87 of 628  | cape town
# Processing Record 88 of 628  | tuatapere
# Processing Record 89 of 628  | tromso
# Processing Record 90 of 628  | hobyo
# Processing Record 91 of 628  | ulaanbaatar
# Processing Record 92 of 628  | mount isa
# Processing Record 93 of 628  | vuktyl
# Processing Record 94 of 628  | port lincoln
# Processing Record 95 of 628  | avera
# Processing Record 96 of 628  | bayangol
# Processing Record 97 of 628  | trairi
# Processing Record 98 of 628  | khalkhal
# Processing Record 99 of 628  | martapura
# Processing Record 100 of 628  | port elizabeth
# City not found. Skipping...
# Processing Record 101 of 628  | necochea
# Processing Record 102 of 628  | meulaboh
# City not found. Skipping...
# Processing Record 103 of 628  | severo-kurilsk
# Processing Record 104 of 628  | port alfred
# Processing Record 105 of 628  | avarua
# Processing Record 106 of 628  | carnarvon
# City not found. Skipping...
# Processing Record 107 of 628  | hithadhoo
# Processing Record 108 of 628  | mataura
# Processing Record 109 of 628  | praia
# Processing Record 110 of 628  | igarka
# Processing Record 111 of 628  | kalga
# Processing Record 112 of 628  | tiksi
# Processing Record 113 of 628  | khatanga
# Processing Record 114 of 628  | fortuna
# Processing Record 115 of 628  | provideniya
# Processing Record 116 of 628  | deputatskiy
# Processing Record 117 of 628  | hukuntsi
# Processing Record 118 of 628  | kruisfontein
# Processing Record 119 of 628  | duldurga
# Processing Record 120 of 628  | gat
# Processing Record 121 of 628  | shenxian
# Processing Record 122 of 628  | whitehorse
# Processing Record 123 of 628  | cananea
# Processing Record 124 of 628  | naze
# Processing Record 125 of 628  | clarksburg
# Processing Record 126 of 628  | luena
# Processing Record 127 of 628  | touros
# Processing Record 128 of 628  | yatou
# Processing Record 129 of 628  | moerai
# City not found. Skipping...
# Processing Record 130 of 628  | mar del plata
# Processing Record 131 of 628  | victor harbor
# Processing Record 132 of 628  | nigde
# Processing Record 517 of 628  | dera bugti
# Processing Record 518 of 628  | bandarbeyla
# Processing Record 519 of 628  | el alto
# Processing Record 520 of 628  | fayaoue
# Processing Record 521 of 628  | camacha
# Processing Record 522 of 628  | salinas
# Processing Record 523 of 628  | sandakan
# Processing Record 524 of 628  | cap-aux-meules
# Processing Record 525 of 628  | port keats
# Processing Record 526 of 628  | quelimane
# Processing Record 527 of 628  | pochutla
# Processing Record 528 of 628  | algeciras
# Processing Record 529 of 628  | kilinochchi
# Processing Record 530 of 628  | taoudenni
# Processing Record 531 of 628  | shenjiamen
# Processing Record 532 of 628  | samfya
# Processing Record 533 of 628  | mehran
# Processing Record 534 of 628  | adrar
# Processing Record 535 of 628  | dudinka
# Processing Record 536 of 628  | mamlyutka
# Processing Record 537 of 628  | mangrol
# Processing Record 538 of 628  | pangody
# Processing Record 539 of 628  | aksarka
# Processing Record 540 of 628  | camocim
# Processing Record 541 of 628  | bima
# Processing Record 542 of 628  | makakilo city
# Processing Record 543 of 628  | altay
# Processing Record 544 of 628  | barra do garcas
# Processing Record 545 of 628  | potiskum
# City not found. Skipping...
# Processing Record 546 of 628  | barra velha
# Processing Record 547 of 628  | kronach
# Processing Record 548 of 628  | lagoa
# Processing Record 549 of 628  | cururupu
# Processing Record 550 of 628  | soyo
# Processing Record 551 of 628  | port macquarie
# Processing Record 552 of 628  | bayburt
# Processing Record 553 of 628  | nenton
# Processing Record 554 of 628  | mumford
# Processing Record 555 of 628  | bubaque
# Processing Record 556 of 628  | west odessa
# Processing Record 557 of 628  | sambava
# Processing Record 558 of 628  | tres lagoas
# Processing Record 559 of 628  | warrington
# Processing Record 560 of 628  | esmeraldas
# Processing Record 561 of 628  | urucara
# City not found. Skipping...
# Processing Record 562 of 628  | sistranda
# Processing Record 563 of 628  | tipitapa
# Processing Record 564 of 628  | laguna
# Processing Record 565 of 628  | auki
# Processing Record 566 of 628  | vila franca do campo
# Processing Record 567 of 628  | muli
# Processing Record 568 of 628  | hohen neuendorf
# Processing Record 569 of 628  | acapulco
# Processing Record 570 of 628  | almaznyy
# City not found. Skipping...
# Processing Record 571 of 628  | bairiki
# Processing Record 572 of 628  | normandin
# -------------------------------
# Data Retrieval Complete
# -------------------------------

# %%
# Create a DataFrame containing 'City ', 'Country', 'Latitude', 'Longitude',  'Temperature', 'Humidity', 'Cloudiness', 'Wind Speed', 'Date'
weather_data = pd.DataFrame(( city_name, country, lats, lngs, temp, humidity, cloud, wind, date), 
                            index=('City ', 'Country', 'Latitude', 'Longitude',  'Temperature', 'Humidity', 'Cloudiness', 'Wind Speed', 'Date'), dtype="int").T
# Display DataFrame

# %%
weather_data.dtypes
# Out:
# City           object
# Country        object
# Latitude       object
# Longitude      object
# Temperature    object
# Humidity       object
# Cloudiness     object
# Wind Speed     object
# Date           object
# dtype: object

# %%
# Drop any rows containing missing values
weather_clean = weather_data.dropna(how='any')
weather_clean
# Out:
#                   City  Country Latitude Longitude Temperature Humidity  \
# 0             Busselton      AU -37.9651    178.58          73       52
# 1                Atuona      PF -51.7503   100.017       78.28       77
# 2    Comodoro Rivadavia      AR -15.8057  -142.222        51.8       54
# 3                Forbes      AU -48.2285  -63.2541          54       88
# 4         Krasnosel'kup      RU -32.2437   146.306       -1.82       90
# ..                  ...     ...      ...       ...         ...      ...
# 567     Hohen Neuendorf      DE  26.1112  -85.0555       53.01       87
# 568  Acapulco de Juárez      MX  9.90949   5.25265       73.85       53
# 569            Almaznyy      RU   36.007   -32.802        51.8       71
# 570     Bairiki Village      KI   49.038  -153.667        80.6       78
# 571           Normandin      CA -22.2443   116.587        24.8      100
#
#     Cloudiness Wind Speed        Date
# 0           60       1.99  1604569891
# 1           11      22.03  1604569885
# 2            0      24.16  1604569789
# 3           60       7.14  1604570366
# 4            0       7.76  1604569979
# ..         ...        ...         ...
# 567         20      11.41  1604570498
# 568         97       5.77  1604570410
# 569         20       8.95  1604570499
# 570         40       6.93  1604570499
# 571         97       3.36  1604569971
#
# [572 rows x 9 columns]

# %%
weather_clean.describe()
# Out:
#          Latitude   Longitude  Temperature    Humidity  Cloudiness  Wind Speed
# count  572.000000  572.000000   572.000000  572.000000  572.000000  572.000000
# mean     0.225749    7.435337    59.509790   71.225524   53.884615    8.737517
# std     51.595929  106.117225    24.105444   21.217740   39.464329    6.535855
# min    -89.576755 -178.243717   -18.800000    6.000000    0.000000    0.450000
# 25%    -45.673657  -88.643247    46.400000   62.000000   11.000000    3.995000
# 50%      2.533884   16.377736    62.600000   75.000000   68.000000    7.000000
# 75%     44.527668  101.297220    78.800000   87.000000   93.000000   11.410000
# max     89.388358  178.758575   102.200000  100.000000  100.000000   42.500000

# %%
# Find any cities with humidty of greater than 100, if none skip this step
weather_cities = weather_clean.loc[(weather_clean['Humidity'] >100)]
weather_cities
# Out:
# Empty DataFrame
# Columns: [City , Country, Latitude, Longitude, Temperature, Humidity, Cloudiness, Wind Speed, Date]
# Index: []

# %%
weather_clean['Latitude'] = pd.to_numeric(weather_clean['Latitude'], downcast="integer")
weather_clean['Temperature'] = pd.to_numeric(weather_clean['Temperature'], downcast="integer")
weather_clean['Humidity'] = pd.to_numeric(weather_clean['Humidity'], downcast="integer")
weather_clean['Cloudiness'] = pd.to_numeric(weather_clean['Cloudiness'], downcast="integer")

weather_clean['Longitude'] = pd.to_numeric(weather_clean['Longitude'], downcast="integer")
# Out:
# C:\Users\pmhu4\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\pmhu4\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\pmhu4\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\pmhu4\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\pmhu4\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
weather_clean['Wind Speed'] = pd.to_numeric(weather_clean['Wind Speed'], downcast="integer")
weather_clean.dtypes
# Out:
# C:\Users\pmhu4\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# City            object
# Country         object
# Latitude       float64
# Longitude      float64
# Temperature    float64
# Humidity          int8
# Cloudiness        int8
# Wind Speed     float64
# Date            object
# dtype: object

# %%
# Create individual scatter plots for temperature, humidty, cloudiness, and wind speed against latitude data

# Create scatter plot of temp vs latitude
plt.scatter(weather_clean['Latitude'], weather_clean['Temperature'], marker='o')

plt.title('Temperature (F) vs Latitude (11/05/2020)')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.grid(True)
plt.savefig("lat_vs_temp.png")
plt.show()

# The scatter plot below is displaying all the individual cities from the data table, use column names to populate the data for each axis, added labels and title
# The results don't seem to highlight any sort of correlation without further analysis of the data

# %%
# Create scatter plot of humidity vs latitude

plt.scatter(weather_clean['Latitude'], weather_clean['Humidity'], marker='o')

plt.title('Temperature (F) vs Humidity (%) (11/05/2020)')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid(True)
plt.savefig("lat_vs_humidity.png")
plt.show()

# The scatter plot below is displaying all the individual cities from the data table, use column names to populate the data for each axis, added labels and title
# The results don't seem to highlight any sort of correlation without further analysis of the data

# %%
# Create scatter plot of cloudiness vs latitude

plt.scatter(weather_clean['Latitude'], weather_clean['Cloudiness'], marker='o')

plt.title('Cloudiness (%) vs Latitude (11/05/2020)')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid(True)
plt.savefig('lat_vs_cloudiness.png')
plt.show()

# The scatter plot below is displaying all the individual cities from the data table, use column names to populate the data for each axis, added labels and title
# The results don't seem to highlight any sort of correlation without further analysis of the data

# %%
# Create scatter plot of wind speed vs latitude

plt.scatter(weather_clean['Latitude'], weather_clean['Wind Speed'], marker='o')

plt.title('Wind Speed (mph) vs Latitude (11/05/2020)')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.grid(True)
plt.savefig('lat_vs_wind.png')
plt.show()

# The scatter plot below is displaying all the individual cities from the data table, use column names to populate the data for each axis, added labels and title
# The results don't seem to highlight any sort of correlation without further analysis of the data, there are possibly some outliers in this data which might skew the results

# %%
# Run a linear regression for each of the above conditions
# Create Data Tables for northern and southern hemispheres 
northern_hemi = weather_clean.loc[(weather_clean['Latitude'] >=0)]
northern_hemi.dtypes
# Out:
# City            object
# Country         object
# Latitude       float64
# Longitude      float64
# Temperature    float64
# Humidity          int8
# Cloudiness        int8
# Wind Speed     float64
# Date            object
# dtype: object

# %%
# northern_hemi['Latitude'] = pd.to_numeric(northern_hemi['Latitude'], downcast="integer")

# %%
southern_hemi = weather_clean.loc[(weather_clean['Latitude'] <0)]
southern_hemi.dtypes
# Out:
# City            object
# Country         object
# Latitude       float64
# Longitude      float64
# Temperature    float64
# Humidity          int8
# Cloudiness        int8
# Wind Speed     float64
# Date            object
# dtype: object

# %%
# Define Data
x_values = northern_hemi['Latitude']
y_values = northern_hemi['Temperature']

# Create Scatter plot
plt.ylabel('Temperature (F)')
plt.xlabel('Latitude')
plt.title('Temperature (F) vs Latitude in the Northern Hemishpere')
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.grid(True)
plt.annotate(line_eq,(0,20),fontsize=15,color="red")
print(f"The r-squared is: {rvalue**2}")
print(f'P-value: {pvalue}')
plt.savefig('Homework_Output/temp_north.png')

print(line_eq)
plt.show()

# Define Data
x_values = southern_hemi['Latitude']
y_values = southern_hemi['Temperature']

# Create Scatter plot
plt.ylabel('Temperature (F)')
plt.xlabel('Latitude')
plt.title('Temperature (F) vs Latitude in the Southern Hemishpere')
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.grid(True)
plt.annotate(line_eq,(-75,35),fontsize=15,color="red")
print(f"The r-squared is: {rvalue**2}")
print(f'P-value: {pvalue}')

correlation = st.pearsonr(x_values, y_values)

plt.savefig('Homework_Output/temp_south.png')

print(line_eq)

plt.show()
print(f"The correlation between both factors is {round(correlation[0],2)}")
# Out:
# The r-squared is: 0.004233801035388852
# P-value: 0.2660933904884549
# y = 0.06x + 58.53
# The r-squared is: 3.756587329331508e-05
# P-value: 0.9189685832223914
# y = -0.01x + 57.46
# The correlation between both factors is -0.01

# %% [markdown]
# When breaking the set of data into Hemispheres North and South it does little to change the plots after seperting the data points. With r-squared values close to zero in both plots, its hard to draw any solid conclusions from the data aside from a lack of correlation. Looking at the datapoints you can see that all latitudes have about the same range of temperatures regardless of latitude, which is surprising.

# %%
# Define Data
x_values = northern_hemi['Latitude']
y_values = northern_hemi['Humidity']

# Create Scatter plot
plt.ylabel('Humidity (%)')
plt.xlabel('Latitude')
plt.title('Humidity (%) vs Latitude in the Northern Hemishpere')
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
print(f"The r-squared is: {rvalue**2}")
print(f'P-value: {pvalue}')

plt.savefig('Homework_Output/humid_north.png')

print(line_eq)
plt.show()

# Define Data
x_values = southern_hemi['Latitude']
y_values = southern_hemi['Humidity']

# Create Scatter plot
plt.ylabel('Humidity (%)')
plt.xlabel('Latitude')
plt.title('Humidity (%) vs Latitude in the Southern Hemishpere')
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50, 25),fontsize=15,color="red")
print(f"The r-squared is: {rvalue**2}")
print(f'P-value: {pvalue}')


plt.savefig('Homework_Output/humid_south.png')
print(line_eq)
plt.show()


correlation = st.pearsonr(x_values, y_values)
print(f"The correlation between both factors is {round(correlation[0],2)}")
# Out:
# The r-squared is: 0.0001500507529917978
# P-value: 0.834332227227928
# y = -0.01x + 70.72
# The r-squared is: 0.0018661055394048908
# P-value: 0.47315715771455835
# y = 0.03x + 73.8
# The correlation between both factors is 0.04

# %% [markdown]
# When breaking the set of data into Hemispheres North and South it does little to change the plots after seperting the data points. With r-squared values close to zero in both plots, its hard to draw any solid conclusions from the data aside from a lack of correlation. Looking at the datapoints you can see that all latitudes have about the same range of humidty values  regardless of latitude.

# %%
# Define Data
x_values = northern_hemi['Latitude']
y_values = northern_hemi['Cloudiness']

# Create Scatter plot
plt.ylabel('Cloudiness (%)')
plt.xlabel('Latitude')
plt.title('Cloudiness (%) vs Latitude in the Northern Hemishpere')
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,25),fontsize=15,color="red")
print(f"The r-squared is: {rvalue**2}")
print(f'P-value: {pvalue}')

plt.savefig('Homework_Output/cloud_north.png')

print(line_eq)
plt.show()

# Define Data
x_values = southern_hemi['Latitude']
y_values = southern_hemi['Cloudiness']

# Create Scatter plot
plt.ylabel('Cloudiness (%)')
plt.xlabel('Latitude')
plt.title('Cloudiness (%) vs Latitude in the Southern Hemishpere')
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,25),fontsize=15,color="red")
print(f"The r-squared is: {rvalue**2}")
print(f'P-value: {pvalue}')
plt.savefig('Homework_Output/cloud_south.png')
print(line_eq)
plt.show()


correlation = st.pearsonr(x_values, y_values)
print(f"The correlation between both factors is {round(correlation[0],2)}")
# Out:
# The r-squared is: 0.0019420778311054047
# P-value: 0.45158636515880235
# y = 0.07x + 51.01
# The r-squared is: 0.001147190788680045
# P-value: 0.5738802796998461
# y = -0.05x + 51.35
# The correlation between both factors is -0.03

# %% [markdown]
# When breaking the set of data into Hemispheres North and South it does little to change the plots after seperting the data points. With r-squared values close to zero in both plots, its hard to draw any solid conclusions from the data aside from a lack of correlation. Looking at the datapoints you can see that all latitudes have about the same range of cloudiness values  regardless of latitude.

# %%
# Define Data
x_values = northern_hemi['Latitude']
y_values = northern_hemi['Wind Speed']

# Create Scatter plot
plt.ylabel('Wind Speed (mph)')
plt.xlabel('Latitude')
plt.title('Wind Speed (mph) vs Latitude in the Northern Hemishpere')
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,25),fontsize=15,color="red")
print(f"The r-squared is: {rvalue**2}")
print(f'P-value: {pvalue}')


plt.savefig('Homework_Output/wind_north.png')
print(line_eq)
plt.show()

# Define Data
x_values = southern_hemi['Latitude']
y_values = southern_hemi['Wind Speed']

# Create Scatter plot
plt.ylabel('Wind Speed (mph)')
plt.xlabel('Latitude')
plt.title('Wind Speed (mph) vs Latitude in the Southern Hemishpere')
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-45,20),fontsize=15,color="red")
print(f"The r-squared is: {rvalue**2}")
print(f'P-value: {pvalue}')



plt.savefig('Homework_Output/humid_south.png')
print(line_eq)
plt.show()


correlation = st.pearsonr(x_values, y_values)
print(f"The correlation between both factors is {round(correlation[0],2)}")
# Out:
# The r-squared is: 0.00038453521885890667
# P-value: 0.7377503821161122
# y = -0.01x + 8.89
# The r-squared is: 0.0006275035666858109
# P-value: 0.6775192632527111
# y = 0.01x + 9.1
# The correlation between both factors is 0.03

# %% [markdown]
# When breaking the set of data into Hemispheres North and South it does little to change the plots after seperting the data points. With r-squared values close to zero in both plots, its hard to draw any solid conclusions from the data aside from a lack of correlation. Looking at the datapoints you can see that all latitudes have about the same range of wind speed values  regardless of latitude.
